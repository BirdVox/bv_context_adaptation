# %%
import itertools
import numpy as np
import os
import sys
sys.path.append("../src")

import localmodule

# %%
import vesper
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-96d80c801aad> in <module>()
# ----> 1 import vesper
#
# ModuleNotFoundError: No module named 'vesper'
